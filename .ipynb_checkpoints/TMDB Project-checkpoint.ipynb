# %% [markdown]
# # Questions for This Dataset
#
# The top 5 highest rated movies?
# The trend of top 10 Genres?
# The average revenue of top 10 directors?
# The relationship between budget and ratings?
# Which genre is becoming more popular?

# %% [markdown]
# # Import the Raw Data

# %%
import pandas as pd 

df = pd.read_csv("tmdb_movies.csv")

#Have a look at the data, limit to 1 rows.
df.head(1)
# Out:
#        id    imdb_id  popularity     budget     revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#                         homepage         director            tagline  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow  The park is open.
#
#        ...                                                overview runtime  \
# 0      ...       Twenty-two years after the events of Jurassic ...     124
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
#
# [1 rows x 21 columns]

# %% [markdown]
# # Select only the columns that will be used to analyse.

# %%
#display the position of all columns, easy to select.
df.columns.to_frame().reset_index()
#The code works on my notebook, no error.
# Out:
#                    index                     0
# 0                     id                    id
# 1                imdb_id               imdb_id
# 2             popularity            popularity
# 3                 budget                budget
# 4                revenue               revenue
# 5         original_title        original_title
# 6                   cast                  cast
# 7               homepage              homepage
# 8               director              director
# 9                tagline               tagline
# 10              keywords              keywords
# 11              overview              overview
# 12               runtime               runtime
# 13                genres                genres
# 14  production_companies  production_companies
# 15          release_date          release_date
# 16            vote_count            vote_count
# 17          vote_average          vote_average
# 18          release_year          release_year
# 19            budget_adj            budget_adj
# 20           revenue_adj           revenue_adj

# %%
#choose the wanted columns
wanted_columns = [5, 8, 13, 16, 17, 18, 19, 20]
df_shorted = df.iloc[:, wanted_columns]
#check the result
display(df_shorted.shape)
df_shorted.head()
# Out:
# (10866, 8)
#                  original_title          director  \
# 0                Jurassic World   Colin Trevorrow
# 1            Mad Max: Fury Road     George Miller
# 2                     Insurgent  Robert Schwentke
# 3  Star Wars: The Force Awakens       J.J. Abrams
# 4                     Furious 7         James Wan
#
#                                       genres  vote_count  vote_average  \
# 0  Action|Adventure|Science Fiction|Thriller        5562           6.5
# 1  Action|Adventure|Science Fiction|Thriller        6185           7.1
# 2         Adventure|Science Fiction|Thriller        2480           6.3
# 3   Action|Adventure|Science Fiction|Fantasy        5292           7.5
# 4                      Action|Crime|Thriller        2947           7.3
#
#    release_year    budget_adj   revenue_adj
# 0          2015  1.379999e+08  1.392446e+09
# 1          2015  1.379999e+08  3.481613e+08
# 2          2015  1.012000e+08  2.716190e+08
# 3          2015  1.839999e+08  1.902723e+09
# 4          2015  1.747999e+08  1.385749e+09

# %%
#compare the runing time between original dataframe and shorted dataframe
import time
#shorted df
start_time = time.time()

df_shorted.isnull().any()

end_time = time.time()
print("Elapsed time was %g seconds" % (end_time - start_time))

#original df
start_time = time.time()

df.isnull().any()

end_time = time.time()
print("Elapsed time was %g seconds" % (end_time - start_time))
# Out:
# Elapsed time was 0.00599718 seconds
# Elapsed time was 0.0190082 seconds

# %%
#save to shorted.csv
df_shorted.to_csv('shorted.csv', index = False)

# %% [markdown]
# # Clean the data

# %%
#import the shorted.csv
df = pd.read_csv('shorted.csv')

# %%
#check null values
df.isnull().any()
# Out:
# original_title    False
# director           True
# genres             True
# vote_count        False
# vote_average      False
# release_year      False
# budget_adj        False
# revenue_adj       False
# dtype: bool

# %%
#check the rows with null values
df[pd.isnull(df).any(axis=1)]
# Out:
#                                           original_title  \
# 424                                       Belli di papÃ
# 532                       Iliza Shlesinger: Freezing Hot
# 548                           Sense8: Creating the World
# 556                                       With This Ring
# 620                                   All Hallows' Eve 2
# 997                 Star Wars Rebels: Spark of Rebellion
# 1032               Marvel Studios: Assembling a Universe
# 1054                                  Unlocking Sherlock
# 1203                                        Free to Play
# 1241                                           Dance-Off
# 1288                   Top Gear: The Perfect Road Trip 2
# 1712                                   Prayers for Bobby
# 1852                             The Diary of Anne Frank
# 1872                                                 Paa
# 1895                      Doctor Who: The Waters of Mars
# 1897              Jonas Brothers: The Concert Experience
# 2221                     Scott Pilgrim vs. the Animation
# 2286                     Bo Burnham: Words, Words, Words
# 2290       Across the Line: The Exodus of Charlie Wright
# 2315                                Listen to Your Heart
# 2318                            Barbie in A Mermaid Tale
# 2370                                     Freshman Father
# 2376                       Doctor Who: A Christmas Carol
# 2397                      The Making of The Walking Dead
# 2401     Opeth: In Live Concert At The Royal Albert Hall
# 2403                     Yu-Gi-Oh! 3D: Bonds Beyond Time
# 2853                                           Vizontele
# 3171   The Assassination of Jesse James: Death Of An ...
# 3224   John Mayer: Where the Light Is Live in Los Ang...
# 3276                                   Kismat Konnection
# ...                                                  ...
# 3910                          Steve Jobs: One Last Thing
# 4547   London 2012 Olympic Opening Ceremony: Isles of...
# 4679                          Barbie in A Mermaid Tale 2
# 4732                                       The Scapegoat
# 4797                             Doctor Who: The Snowmen
# 4872                                         Party Bercy
# 4890                          Cousin Ben Troop Screening
# 4939                           The Men Who Built America
# 5413              The Brave Little Toaster to the Rescue
# 5830                  Doctor Who: The Time of the Doctor
# 5866                                              Jinxed
# 5915                    Phineas and Ferb: Mission Marvel
# 5934                                        Prada: Candy
# 5972                     Top Gear: The Perfect Road Trip
# 6033                      Russell Brand: Messiah Complex
# 6043                                      Bombay Talkies
# 6181                             North and South, Book I
# 6530                                         Saw Rebirth
# 7579                                       La hora frÃ­a
# 7767                       Doctor Who: The Runaway Bride
# 7814                            Transformers: Beginnings
# 8234                                     Viaggi di nozze
# 8614                          T2 3-D: Battle Across Time
# 8878                     Mom's Got a Date With a Vampire
# 9307                                           Goldeneye
# 9593                                           Peter Pan
# 9799                                         The Amputee
# 10386     The Making of 'The Nightmare Before Christmas'
# 10426                               Magical Mystery Tour
# 10659                      The Party at Kitty and Stud's
#
#                                                 director  \
# 424                                         Guido Chiesa
# 532                                                  NaN
# 548                                                  NaN
# 556                                                  NaN
# 620    Antonio Padovan|Bryan Norton|Marc Roussel|Ryan...
# 997                            Steward Lee|Steven G. Lee
# 1032                                                 NaN
# 1054                                                 NaN
# 1203                                                 NaN
# 1241                                                 NaN
# 1288                                                 NaN
# 1712                                     Russell Mulcahy
# 1852                                                 NaN
# 1872                                                 NaN
# 1895                                                 NaN
# 1897                                     Bruce Hendricks
# 2221                                                 NaN
# 2286                                                 NaN
# 2290                                                 NaN
# 2315                                                 NaN
# 2318                                                 NaN
# 2370                                       Michael Scott
# 2376                                                 NaN
# 2397                                                 NaN
# 2401                                                 NaN
# 2403                                                 NaN
# 2853                                    YÄ±lmaz ErdoÄŸan
# 3171                                                 NaN
# 3224                                                 NaN
# 3276                                                 NaN
# ...                                                  ...
# 3910                                                 NaN
# 4547                                         Danny Boyle
# 4679                                                 NaN
# 4732                                   Charles Sturridge
# 4797                                                 NaN
# 4872                                                 NaN
# 4890                                        Wes Anderson
# 4939                                                 NaN
# 5413                                                 NaN
# 5830                                         James Payne
# 5866                                                 NaN
# 5915                                                 NaN
# 5934                          Wes Anderson|Roman Coppola
# 5972                                                 NaN
# 6033                                                 NaN
# 6043   Anurag Kashyap|Dibakar Banerjee|Zoya Akhtar|Ka...
# 6181                                                 NaN
# 6530                            Jeff Shuter|Daniel Viney
# 7579                                                 NaN
# 7767                                                 NaN
# 7814                                                 NaN
# 8234                                       Carlo Verdone
# 8614                                       James Cameron
# 8878                                         Steve Boyum
# 9307                                            Don Boyd
# 9593                                                 NaN
# 9799                                         David Lynch
# 10386                                                NaN
# 10426                                                NaN
# 10659                                       Morton Lewis
#
#                                                 genres  vote_count  \
# 424                                                NaN          21
# 532                                             Comedy          14
# 548                        Documentary|Science Fiction          12
# 556                                     Comedy|Romance          14
# 620                                                NaN          13
# 997                                                NaN          13
# 1032                              TV Movie|Documentary          32
# 1054                              TV Movie|Documentary          11
# 1203                                       Documentary          40
# 1241                              Romance|Music|Comedy          18
# 1288                                       Documentary          12
# 1712                                               NaN          57
# 1852                                             Drama          19
# 1872                              Drama|Family|Foreign          11
# 1895                  Science Fiction|Adventure|Family          25
# 1897                                               NaN          11
# 2221                      TV Movie|Animation|Adventure          19
# 2286                                            Comedy          13
# 2290                       Drama|Action|Thriller|Crime          11
# 2315                               Drama|Music|Romance          29
# 2318                          Animation|Family|Fantasy          35
# 2370                                               NaN          12
# 2376                                               NaN          11
# 2397                                       Documentary          42
# 2401                                             Music          10
# 2403                                 Animation|Fantasy          10
# 2853                                               NaN          12
# 3171                                       Documentary          20
# 3224                                             Music          16
# 3276                      Drama|Comedy|Romance|Foreign          11
# ...                                                ...         ...
# 3910                                       Documentary          11
# 4547                                               NaN          12
# 4679                                  Animation|Family          22
# 4732                                               NaN          12
# 4797                                               NaN          10
# 4872                                            Comedy          15
# 4890                                               NaN          14
# 4939                               Documentary|History          11
# 5413                           Animation|Comedy|Family          11
# 5830                                               NaN          26
# 5866                             Family|Fantasy|Comedy          19
# 5915                  Action|Adventure|Science Fiction          13
# 5934                                               NaN          27
# 5972             TV Movie|Action|Adventure|Documentary          35
# 6033                                            Comedy          12
# 6043                                               NaN          12
# 6181                             Drama|History|Western          17
# 6530                                               NaN          24
# 7579   Horror|Thriller|Science Fiction|Mystery|Foreign          10
# 7767                          Science Fiction|TV Movie          18
# 7814         Animation|Action|Thriller|Science Fiction          34
# 8234                                               NaN          44
# 8614                                               NaN          14
# 8878                                               NaN          16
# 9307                                               NaN          10
# 9593         Action|Adventure|Animation|Family|Fantasy          28
# 9799                                               NaN          11
# 10386                                      Documentary          15
# 10426                                            Music          15
# 10659                                              NaN          10
#
#        vote_average  release_year    budget_adj   revenue_adj
# 424             6.1          2015  0.000000e+00  0.000000e+00
# 532             6.6          2015  0.000000e+00  0.000000e+00
# 548             7.5          2015  0.000000e+00  0.000000e+00
# 556             6.5          2015  0.000000e+00  0.000000e+00
# 620             5.0          2015  0.000000e+00  0.000000e+00
# 997             6.8          2014  0.000000e+00  0.000000e+00
# 1032            6.3          2014  0.000000e+00  0.000000e+00
# 1054            7.2          2014  0.000000e+00  0.000000e+00
# 1203            7.0          2014  1.381637e+05  0.000000e+00
# 1241            5.7          2014  0.000000e+00  0.000000e+00
# 1288            6.8          2014  0.000000e+00  0.000000e+00
# 1712            7.4          2009  0.000000e+00  0.000000e+00
# 1852            7.5          2009  0.000000e+00  0.000000e+00
# 1872            6.1          2009  3.303301e+06  0.000000e+00
# 1895            8.0          2009  0.000000e+00  0.000000e+00
# 1897            7.0          2009  0.000000e+00  0.000000e+00
# 2221            7.7          2010  0.000000e+00  0.000000e+00
# 2286            6.5          2010  0.000000e+00  0.000000e+00
# 2290            6.0          2010  0.000000e+00  0.000000e+00
# 2315            7.3          2010  0.000000e+00  0.000000e+00
# 2318            6.3          2010  0.000000e+00  0.000000e+00
# 2370            5.8          2010  0.000000e+00  0.000000e+00
# 2376            7.7          2010  0.000000e+00  0.000000e+00
# 2397            8.4          2010  0.000000e+00  0.000000e+00
# 2401            8.6          2010  0.000000e+00  0.000000e+00
# 2403            6.0          2010  0.000000e+00  0.000000e+00
# 2853            7.2          2001  0.000000e+00  0.000000e+00
# 3171            6.8          2008  0.000000e+00  0.000000e+00
# 3224            8.5          2008  0.000000e+00  0.000000e+00
# 3276            5.8          2008  4.233448e+06  1.114065e+07
# ...             ...           ...           ...           ...
# 3910            6.6          2011  0.000000e+00  0.000000e+00
# 4547            8.3          2012  0.000000e+00  0.000000e+00
# 4679            6.0          2012  0.000000e+00  0.000000e+00
# 4732            6.2          2012  0.000000e+00  0.000000e+00
# 4797            7.8          2012  0.000000e+00  0.000000e+00
# 4872            6.4          2012  0.000000e+00  0.000000e+00
# 4890            7.0          2012  0.000000e+00  0.000000e+00
# 4939            5.3          2012  0.000000e+00  0.000000e+00
# 5413            7.0          1997  0.000000e+00  0.000000e+00
# 5830            8.5          2013  0.000000e+00  0.000000e+00
# 5866            7.0          2013  4.680167e+06  0.000000e+00
# 5915            5.9          2013  0.000000e+00  0.000000e+00
# 5934            6.9          2013  0.000000e+00  0.000000e+00
# 5972            7.6          2013  0.000000e+00  0.000000e+00
# 6033            6.8          2013  0.000000e+00  0.000000e+00
# 6043            5.9          2013  0.000000e+00  0.000000e+00
# 6181            6.0          1985  0.000000e+00  0.000000e+00
# 6530            5.9          2005  0.000000e+00  0.000000e+00
# 7579            4.9          2007  0.000000e+00  0.000000e+00
# 7767            7.6          2007  0.000000e+00  0.000000e+00
# 7814            5.8          2007  0.000000e+00  0.000000e+00
# 8234            6.7          1995  0.000000e+00  0.000000e+00
# 8614            6.7          1996  0.000000e+00  0.000000e+00
# 8878            5.4          2000  0.000000e+00  0.000000e+00
# 9307            5.3          1989  0.000000e+00  0.000000e+00
# 9593            6.6          1988  0.000000e+00  0.000000e+00
# 9799            5.0          1974  0.000000e+00  0.000000e+00
# 10386           7.5          1993  0.000000e+00  0.000000e+00
# 10426           5.8          1967  0.000000e+00  0.000000e+00
# 10659           3.0          1970  2.808184e+04  0.000000e+00
#
# [65 rows x 8 columns]

# %%
#delete the rows with null values
df = df.dropna(how='any')

# %%
#check the result
display(df.shape)
df.isnull().any()
# Out:
# (10801, 8)
# original_title    False
# director          False
# genres            False
# vote_count        False
# vote_average      False
# release_year      False
# budget_adj        False
# revenue_adj       False
# dtype: bool

# %%
#check duplicates
df.duplicated().any().sum()
# Out:
# 1

# %%
#take a look at the duplicated row
df[df.duplicated()]
# Out:
#      original_title          director  \
# 2090         TEKKEN  Dwight H. Little
#
#                                            genres  vote_count  vote_average  \
# 2090  Crime|Drama|Action|Thriller|Science Fiction         110           5.0
#
#       release_year  budget_adj  revenue_adj
# 2090          2010  30000000.0     967000.0

# %%
#drop duplicates
df = df.drop_duplicates()

# %%
#check the result
df.duplicated().any()
# Out:
# False

# %%
#save to cleaned.csv
df.to_csv('cleaned.csv', index=False)

# %% [markdown]
# # Import cleaned data

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set(color_codes=True)
% matplotlib inline 

df = pd.read_csv('cleaned.csv')
display(df.shape)
df.head()
# Out:
# (10800, 8)
#                  original_title          director  \
# 0                Jurassic World   Colin Trevorrow
# 1            Mad Max: Fury Road     George Miller
# 2                     Insurgent  Robert Schwentke
# 3  Star Wars: The Force Awakens       J.J. Abrams
# 4                     Furious 7         James Wan
#
#                                       genres  vote_count  vote_average  \
# 0  Action|Adventure|Science Fiction|Thriller        5562           6.5
# 1  Action|Adventure|Science Fiction|Thriller        6185           7.1
# 2         Adventure|Science Fiction|Thriller        2480           6.3
# 3   Action|Adventure|Science Fiction|Fantasy        5292           7.5
# 4                      Action|Crime|Thriller        2947           7.3
#
#    release_year    budget_adj   revenue_adj
# 0          2015  1.379999e+08  1.392446e+09
# 1          2015  1.379999e+08  3.481613e+08
# 2          2015  1.012000e+08  2.716190e+08
# 3          2015  1.839999e+08  1.902723e+09
# 4          2015  1.747999e+08  1.385749e+09

# %% [markdown]
# # Q1 The top 5 highest rated movies

# %%
#sort by vote_average
df_top_rated = df.sort_values(by=['vote_average'], ascending=False)
df_top_rated.head()
# Out:
#                      original_title                director  \
# 3858  The Story of Film: An Odyssey            Mark Cousins
# 536            The Mask You Live In  Jennifer Siebel Newsom
# 1192  Black Mirror: White Christmas           Carl Tibbetts
# 2251                    Life Cycles        Derek Frankowski
# 6857              Pink Floyd: Pulse            David Mallet
#
#                                              genres  vote_count  vote_average  \
# 3858                                    Documentary          14           9.2
# 536                                     Documentary          11           8.9
# 1192  Drama|Horror|Mystery|Science Fiction|Thriller          41           8.8
# 2251                                    Documentary          27           8.8
# 6857                                          Music          23           8.7
#
#       release_year  budget_adj  revenue_adj
# 3858          2011         0.0          0.0
# 536           2015         0.0          0.0
# 1192          2014         0.0          0.0
# 2251          2010         0.0          0.0
# 6857          2006         0.0          0.0

# %% [markdown]
# It can be noticed that the top 5 rated movies have quite small vote counts. It is necessary to look at the distribution of vote counts.

# %%
df.vote_count.describe()
# Out:
# count    10800.000000
# mean       218.600741
# std        577.165055
# min         10.000000
# 25%         17.000000
# 50%         39.000000
# 75%        147.000000
# max       9767.000000
# Name: vote_count, dtype: float64

# %%
plt.hist(df.vote_count)
plt.title('The Histgram of movies based on vote counts')
plt.ylabel('Number of movies')
plt.xlabel('Vote Count');

# %%
#derive the top 5 rated movies in 4 groups divided by the quartiles 
criteria = ['vote_count <=17', 'vote_count > 17 and vote_count<=38', 'vote_count >38 and vote_count<=146', 'vote_count>146']
def top_5_movies(df):
    quartiles = ['First', 'Second', 'Third', 'Fourth']
    data = []
    for c in criteria:
        group = df.query(c).sort_values(by=['vote_average'], ascending=False).head().reset_index().iloc[:, [1, 4, 5]]
        group.index=range(1,6)
        group.columns=['Title', 'Count', 'Rating']
        data.append(group)
    df_combined = pd.concat(
        [df.rename(columns=lambda x: x.zfill(4)) for df in data], keys=['Top 5 Movies in {} Quartiles'.format(a) for a in quartiles], axis =0)
    display(df_combined)   
top_5_movies(df)
# Out:
#                                                                                 Title  \
# Top 5 Movies in First Quartiles  1                      The Story of Film: An Odyssey
#                                  2                               The Mask You Live In
#                                  3                Dave Chappelle: Killin' Them Softly
#                                  4  A Personal Journey with Martin Scorsese Throug...
#                                  5                              Queen - Rock Montreal
# Top 5 Movies in Second Quartiles 1                                        Life Cycles
#                                  2                                  Pink Floyd: Pulse
#                                  3                                            Tropico
#                                  4                                  Stop Making Sense
#                                  5                            Iron Maiden: Flight 666
# Top 5 Movies in Third Quartiles  1                      Black Mirror: White Christmas
#                                  2                                  The Art of Flight
#                                  3      The Jinx: The Life and Deaths of Robert Durst
#                                  4   Dear Zachary: A Letter to a Son About His Father
#                                  5                                  World of Tomorrow
# Top 5 Movies in Fourth Quartiles 1                           The Shawshank Redemption
#                                  2                                      The Godfather
#                                  3                                           Whiplash
#                                  4                                       Forrest Gump
#                                  5                                    The Dark Knight
#
#                                     Count  Rating
# Top 5 Movies in First Quartiles  1     14     9.2
#                                  2     11     8.9
#                                  3     17     8.5
#                                  4     11     8.5
#                                  5     14     8.5
# Top 5 Movies in Second Quartiles 1     27     8.8
#                                  2     23     8.7
#                                  3     24     8.4
#                                  4     23     8.4
#                                  5     28     8.3
# Top 5 Movies in Third Quartiles  1     41     8.8
#                                  2     60     8.5
#                                  3     72     8.4
#                                  4     74     8.3
#                                  5     47     8.2
# Top 5 Movies in Fourth Quartiles 1   5754     8.4
#                                  2   3970     8.3
#                                  3   2372     8.2
#                                  4   4856     8.1
#                                  5   8432     8.1

# %% [markdown]
# # Q2 The trend of top 10 genres?

# %%
#choose top 5 genres based on counts
df_genres = df.genres.value_counts().to_frame().head(5)
df_genres
# Out:
#                genres
# Drama             711
# Comedy            707
# Documentary       306
# Drama|Romance     289
# Comedy|Drama      280

# %%
#display the line chart of the top 10 genres
def trend(df):
    data = []
    for genre in df_genres.index.tolist():
        #display(genre)
        df1 = df[df.genres==genre].groupby(['release_year']).count()[['genres']]
        data.append((df1, genre))
    #return data
    f, ax = plt.subplots()
    for n in data:
        plt.plot(n[0], label=n[1])
    plt.legend()
    plt.title("The Trend of Top 5 Genres")

trend(df)

# %% [markdown]
# According to the graphs, the number of drama, comedy, documentary, horror movies have a dramastic increase.
# The number of drama and romance movie had a sharp decline after 2010.
# More data would  be needed to answer the why question.

# %% [markdown]
# # Q3 The relationship between director and revenues?
# Which director has the highest average revenue per movie.
# The average rating of their movies.

# %%
#find out the top 10 directors based on number of movies they have directed
top_10 = df.director.value_counts().head(10).index.tolist()
top_10
# Out:
# ['Woody Allen',
#  'Clint Eastwood',
#  'Steven Spielberg',
#  'Martin Scorsese',
#  'Ridley Scott',
#  'Ron Howard',
#  'Steven Soderbergh',
#  'Joel Schumacher',
#  'Brian De Palma',
#  'Tim Burton']

# %%
#filter the dataframe to includes only the top 10 directors
df_director = df[df.director.isin(top_10)]
df_director.head()
# Out:
#               original_title          director  \
# 7                The Martian      Ridley Scott
# 33           Bridge of Spies  Steven Spielberg
# 66   In the Heart of the Sea        Ron Howard
# 155           Irrational Man       Woody Allen
# 568             The Audition   Martin Scorsese
#
#                                       genres  vote_count  vote_average  \
# 7            Drama|Adventure|Science Fiction        4572           7.6
# 33                            Thriller|Drama        1638           7.1
# 66   Thriller|Drama|Adventure|Action|History         805           6.4
# 155                            Mystery|Drama         319           6.1
# 568                                   Comedy          10           6.1
#
#      release_year    budget_adj   revenue_adj
# 7            2015  9.935996e+07  5.477497e+08
# 33           2015  3.679998e+07  1.496016e+08
# 66           2015  9.199996e+07  8.631506e+07
# 155          2015  1.012000e+07  2.519979e+07
# 568          2015  0.000000e+00  0.000000e+00

# %%
#calculate the average revenue based on directors, sort by revenue
avg_rev = df_director.groupby(['director']).revenue_adj.mean().to_frame().sort_values(by=['revenue_adj'], ascending=False).reset_index()
avg_rev.index = range(1,11)
avg_rev
# Out:
#              director   revenue_adj
# 1    Steven Spielberg  5.242223e+08
# 2          Tim Burton  2.383834e+08
# 3          Ron Howard  2.057771e+08
# 4        Ridley Scott  1.834594e+08
# 5   Steven Soderbergh  1.125124e+08
# 6      Clint Eastwood  1.076379e+08
# 7     Joel Schumacher  9.975845e+07
# 8     Martin Scorsese  8.367386e+07
# 9      Brian De Palma  8.247938e+07
# 10        Woody Allen  2.876045e+07

# %%
#The aveage rating of the top 10 directors
avg_rating = df_director.groupby(['director']).vote_average.mean().to_frame().sort_values(by=['vote_average'], ascending=False).reset_index()
avg_rating.index = range(1,11)
avg_rating
# Out:
#              director  vote_average
# 1     Martin Scorsese      6.958621
# 2    Steven Spielberg      6.824138
# 3          Tim Burton      6.642105
# 4      Clint Eastwood      6.508824
# 5        Ridley Scott      6.478261
# 6         Woody Allen      6.444444
# 7          Ron Howard      6.377273
# 8      Brian De Palma      6.355000
# 9   Steven Soderbergh      6.172727
# 10    Joel Schumacher      5.971429

# %%
#join those two dataframe together
result = pd.merge(avg_rev, avg_rating, on='director')
result
# Out:
#             director   revenue_adj  vote_average
# 0   Steven Spielberg  5.242223e+08      6.824138
# 1         Tim Burton  2.383834e+08      6.642105
# 2         Ron Howard  2.057771e+08      6.377273
# 3       Ridley Scott  1.834594e+08      6.478261
# 4  Steven Soderbergh  1.125124e+08      6.172727
# 5     Clint Eastwood  1.076379e+08      6.508824
# 6    Joel Schumacher  9.975845e+07      5.971429
# 7    Martin Scorsese  8.367386e+07      6.958621
# 8     Brian De Palma  8.247938e+07      6.355000
# 9        Woody Allen  2.876045e+07      6.444444

# %%
sns.set(style='dark')

f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
f.suptitle('Avg Revenue and Ratings of Top 10 Directors')

#f.subplotParams(wspace=0.4)
#plot the revenue
sns.set_color_codes("pastel")
sns.barplot(x='revenue_adj', y='director', data = result, label="Average Revenue", color="b", ax = ax1)

#plot the rating
sns.set_color_codes('pastel')
sns.barplot(x='vote_average', y='director', data = result, label='Average Rating', color='b', ax = ax2)

#add a legend and information axis label
ax1.set(ylabel='', xlabel='Revenue');
ax2.set(xlim=(5.5,7.5), ylabel='', xlabel='Rating')
ax1.yaxis.tick_right()
ax1.invert_xaxis()

f.tight_layout()

# %% [markdown]
# # Q4 The relationship between revenue and ratings?

# %%
import seaborn as sns 
sns.set(color_codes=True)
df1 = df.query('vote_count >= 146')
print(df1.shape)
sns.regplot(y='revenue_adj', x='vote_average', data=df1)
plt.title('Relationship Between Revenue and Ratings')
# Out:
# (2717, 8)
# Text(0.5,1,'Relationship Between Revenue and Ratings')

# %% [markdown]
# No clear relationship between revenue and ratings.

# %% [markdown]
# # Q5 Which genre become more popular?

# %%
#get a set of genres
list_geners = df.genres.apply(lambda x: x.split("|")).tolist()
genres = set(x for l in list_geners for x in l)
genres = list(genres)
genres
# Out:
# ['Western',
#  'Documentary',
#  'Family',
#  'Mystery',
#  'Music',
#  'Comedy',
#  'Adventure',
#  'Science Fiction',
#  'Thriller',
#  'Drama',
#  'Animation',
#  'Crime',
#  'War',
#  'Action',
#  'History',
#  'Horror',
#  'Foreign',
#  'TV Movie',
#  'Romance',
#  'Fantasy']

# %%
#assign 1 or 0 to each genre to count
def genre_count(df):
    for genre in genres:
        df[genre] =(df.genres.str.contains(genre)).map({False: 0, True: 1})

# %%
def table(df):
    appended_data = []
    for year in range(2005,2015):
        df1 = df.query('release_year =={}'.format(year)).copy()
        genre_count(df1)
        #display(df1.head(1))
        df2 = df1.iloc[:, 8:].astype(int)
        count = df2.sum().to_frame().T
        count.index =[year]
       #display(df2.head(1))
        total = count.sum(axis=1).tolist()[0]
        count = count/total
        #display(count.head())
        appended_data.append(count)
        #display(appended_data) 
    df3 = pd.concat(appended_data)
    #display(df_genres)
    return df3

# %%
df3 = table(df)
df4 = df3[df3>0.05].dropna(axis=1)
df4
# Out:
#         Comedy  Thriller     Drama    Action    Horror
# 2005  0.152941  0.098396  0.194652  0.074866  0.059893
# 2006  0.148467  0.109195  0.188697  0.076628  0.053640
# 2007  0.135426  0.110314  0.176682  0.084305  0.069955
# 2008  0.135179  0.103420  0.188925  0.079805  0.061889
# 2009  0.146558  0.116210  0.164323  0.079941  0.066617
# 2010  0.140821  0.111484  0.174350  0.088852  0.065381
# 2011  0.134691  0.114330  0.167580  0.090055  0.061081
# 2012  0.137795  0.125984  0.182677  0.077953  0.081890
# 2013  0.126093  0.127551  0.184402  0.086735  0.074344
# 2014  0.125941  0.122519  0.194387  0.088296  0.071869

# %%
fig = plt.figure(figsize=(9,7), dpi=100)
ax = plt.subplot(111)
ax.plot(df4)
plt.title("Percentage of Top 5 Genres Over the Years")
plt.xlabel('Year')
plt.ylabel('Percentage')
#the original code works on my notebook
ax.legend(labels=df4.columns)
plt.show()

# %% [markdown]
# It can be noticed that the overall proportion of the above genres have not changed too much from 2006-2014.
# The ranking remain the same as drama comes the first, followed by comedy, thriller, action and horror.
# Drama remained in the first the whole period. Thriller became the second in 2013, while thirller became third.
# In 2012, horror became fourth, ranked before action.

# %% [markdown]
# # Limitation
# The main limition is that the data cannot representing the populatiion correctly. As the data are collected from those who are willing to rate the movies. There is a large group of polutaion is not represented in the dataset.
